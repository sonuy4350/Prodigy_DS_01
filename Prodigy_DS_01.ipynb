# %% [markdown]
# # Prodigy Infotech – Data Science Internship
# ## Task 01: Data Visualization
#
# ### Objective
# To visualize the distribution of a population dataset using a bar chart and histogram.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = {
    "Age": [18, 22, 25, 30, 35, 40, 45, 50, 28, 32, 36, 42],
    "Gender": ["Male", "Female", "Female", "Male", "Male", "Female",
               "Male", "Female", "Male", "Female", "Male", "Female"]
}

df = pd.DataFrame(data)
df
# Out:
#     Age  Gender
# 0    18    Male
# 1    22  Female
# 2    25  Female
# 3    30    Male
# 4    35    Male
# 5    40  Female
# 6    45    Male
# 7    50  Female
# 8    28    Male
# 9    32  Female
# 10   36    Male
# 11   42  Female

# %% [markdown]
# ## Histogram – Age Distribution

# %%
plt.figure(figsize=(8,5))
plt.hist(df["Age"], bins=5)
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Distribution of Ages in Population")
plt.show()

# %% [markdown]
# ## Bar Chart – Gender Distribution

# %%
gender_counts = df["Gender"].value_counts()

plt.figure(figsize=(6,4))
plt.bar(gender_counts.index, gender_counts.values)
plt.xlabel("Gender")
plt.ylabel("Count")
plt.title("Gender Distribution in Population")
plt.show()

# %% [markdown]
# ## Conclusion
# The histogram shows the distribution of ages across the population, highlighting the most frequent age groups.
# The bar chart represents the gender distribution, making it easy to compare the count of males and females.
